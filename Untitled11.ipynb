# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('/content/drive/MyDrive/Data/Telcom-Customer-Churn.csv')
df.head().T
# Out:
#                                  0             1               2  \
# customerID              7590-VHVEG    5575-GNVDE      3668-QPYBK
# gender                      Female          Male            Male
# SeniorCitizen                    0             0               0
# Partner                        Yes            No              No
# Dependents                      No            No              No
# tenure                           1            34               2
# PhoneService                    No           Yes             Yes
# MultipleLines     No phone service            No              No
# InternetService                DSL           DSL             DSL
# OnlineSecurity                  No           Yes             Yes
# OnlineBackup                   Yes            No             Yes
# DeviceProtection                No           Yes              No
# TechSupport                     No            No              No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df['TotalCharges']=pd.to_numeric(df['TotalCharges'],errors='coerce')

# %%
df.isna().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['TotalCharges'].hist()
# Out:
# <Axes: >

# %%
df['TotalCharges'].fillna(df['TotalCharges'].median(),inplace=True)

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2281.916928
# std         0.368612    24.559481       30.090047   2265.270398
# min         0.000000     0.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.500000    402.225000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df.drop('customerID',axis=1,inplace=True)

# %%
df.describe(include='O')
# Out:
#        gender Partner Dependents PhoneService MultipleLines InternetService  \
# count    7043    7043       7043         7043          7043            7043
# unique      2       2          2            2             3               3
# top      Male      No         No          Yes            No     Fiber optic
# freq     3555    3641       4933         6361          3390            3096
#
#        OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# count            7043         7043             7043        7043        7043
# unique              3            3                3           3           3
# top                No           No               No          No          No
# freq             3498         3088             3095        3473        2810
#
#        StreamingMovies        Contract PaperlessBilling     PaymentMethod  \
# count             7043            7043             7043              7043
# ...

# %%
df[df.Churn == 'Yes']
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 2       Male              0      No         No       2          Yes
# 4     Female              0      No         No       2          Yes
# 5     Female              0      No         No       8          Yes
# 8     Female              0     Yes         No      28          Yes
# 13      Male              0      No         No      49          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7021    Male              0      No         No      12          Yes
# 7026  Female              0      No         No       9          Yes
# 7032    Male              1      No         No       1          Yes
# 7034  Female              0      No         No      67          Yes
# 7041    Male              1     Yes         No       4          Yes
#
#      MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 2               No             DSL            Yes          Yes
# ...

# %%
# تحويل القيم النصية 'Yes' و 'No' إلى أرقام 1 و 0
df['Churn'] = df['Churn'].map({'Yes': 1, 'No': 0})

# التأكد من أن التحويل تم بنجاح
print(df['Churn'].head())
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Churn, dtype: int64

# %%
df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
df['SeniorCitizen'].astype('O')
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: SeniorCitizen, Length: 7043, dtype: object

# %%
numerical=df.select_dtypes(include=np.number)
categorical=df.select_dtypes(include=object)

# %%
numerical
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges  Churn
# 0                 0       1           29.85         29.85      0
# 1                 0      34           56.95       1889.50      0
# 2                 0       2           53.85        108.15      1
# 3                 0      45           42.30       1840.75      0
# 4                 0       2           70.70        151.65      1
# ...             ...     ...             ...           ...    ...
# 7038              0      24           84.80       1990.50      0
# 7039              0      72          103.20       7362.90      0
# 7040              0      11           29.60        346.45      0
# 7041              1       4           74.40        306.60      1
# 7042              0      66          105.65       6844.50      0
#
# [7043 rows x 5 columns]

# %%
categorical
# Out:
#       gender Partner Dependents PhoneService     MultipleLines  \
# 0     Female     Yes         No           No  No phone service
# 1       Male      No         No          Yes                No
# 2       Male      No         No          Yes                No
# 3       Male      No         No           No  No phone service
# 4     Female      No         No          Yes                No
# ...      ...     ...        ...          ...               ...
# 7038    Male     Yes        Yes          Yes               Yes
# 7039  Female     Yes        Yes          Yes               Yes
# 7040  Female     Yes        Yes           No  No phone service
# 7041    Male     Yes         No          Yes               Yes
# 7042    Male      No         No          Yes                No
#
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No          No
# ...

# %%
numerical.corr()
# Out:
#                 SeniorCitizen    tenure  MonthlyCharges  TotalCharges  \
# SeniorCitizen        1.000000  0.016567        0.220173      0.102652
# tenure               0.016567  1.000000        0.247900      0.825464
# MonthlyCharges       0.220173  0.247900        1.000000      0.650864
# TotalCharges         0.102652  0.825464        0.650864      1.000000
# Churn                0.150889 -0.352229        0.193356     -0.199037
#
#                    Churn
# SeniorCitizen   0.150889
# tenure         -0.352229
# MonthlyCharges  0.193356
# TotalCharges   -0.199037
# Churn           1.000000

# %%
global_mean=df['Churn'].mean()

# %%
global_mean
# Out:
# 0.2653698707936959

# %%
numerical=df.select_dtypes(include=np.number)
categorical=df.select_dtypes(include=object)

# %%
categorical
# Out:
#       gender Partner Dependents PhoneService     MultipleLines  \
# 0     Female     Yes         No           No  No phone service
# 1       Male      No         No          Yes                No
# 2       Male      No         No          Yes                No
# 3       Male      No         No           No  No phone service
# 4     Female      No         No          Yes                No
# ...      ...     ...        ...          ...               ...
# 7038    Male     Yes        Yes          Yes               Yes
# 7039  Female     Yes        Yes          Yes               Yes
# 7040  Female     Yes        Yes           No  No phone service
# 7041    Male     Yes         No          Yes               Yes
# 7042    Male      No         No          Yes                No
#
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No          No
# ...

# %%
cat_col=categorical.columns

# %%
cat_col
# Out:
# Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod'],
#       dtype='object')

# %%
catgroy=cat_col.array

# %%
for col in catgroy:
   mean_col=df.groupby(col).Churn.agg(['mean'])
   mean_col['risk']=mean_col/global_mean
   display(mean_col)
#
# Out:
#             mean      risk
# gender
# Female  0.269209  1.014466
# Male    0.261603  0.985807
#              mean      risk
# Partner
# No       0.329580  1.241964
# Yes      0.196649  0.741038
#                 mean      risk
# Dependents
# No          0.312791  1.178700
# Yes         0.154502  0.582215
#                   mean      risk
# PhoneService
# No            0.249267  0.939319
# Yes           0.267096  1.006506
#                       mean      risk
# MultipleLines
# No                0.250442  0.943749
# No phone service  0.249267  0.939319
# Yes               0.286099  1.078114
#                      mean      risk
# InternetService
# DSL              0.189591  0.714441
# Fiber optic      0.418928  1.578656
# No               0.074050  0.279044
#                          mean      risk
# OnlineSecurity
# No                   0.417667  1.573906
# No internet service  0.074050  0.279044
# Yes                  0.146112  0.550597
#                          mean      risk
# ...

# %%
for col in catgroy:
   mean_col=df.groupby(col).Churn.agg(['mean'])
   graph=sns.barplot(x=col,y='mean',data=mean_col,palette='Greens')
   graph.axhline(global_mean,linewidth=3,color='red')
   plt.text(0,global_mean -.03,"global_mean",color='black',weight='semibold')
   plt.show()

#
# Out:
# <ipython-input-213-8822c14db417>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   graph=sns.barplot(x=col,y='mean',data=mean_col,palette='Greens')
# <ipython-input-213-8822c14db417>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   graph=sns.barplot(x=col,y='mean',data=mean_col,palette='Greens')
# <ipython-input-213-8822c14db417>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   graph=sns.barplot(x=col,y='mean',data=mean_col,palette='Greens')
# <ipython-input-213-8822c14db417>:3: FutureWarning:
#
# ...

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
x=df[['InternetService','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','Contract','PaymentMethod','StreamingTV','StreamingMovies']]
y=df['Churn']

# %%
x
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No          No
# 1                DSL            Yes           No              Yes          No
# 2                DSL            Yes          Yes               No          No
# 3                DSL            Yes           No              Yes         Yes
# 4        Fiber optic             No           No               No          No
# ...              ...            ...          ...              ...         ...
# 7038             DSL            Yes           No              Yes         Yes
# 7039     Fiber optic             No          Yes              Yes          No
# 7040             DSL            Yes           No               No          No
# 7041     Fiber optic             No           No               No          No
# 7042     Fiber optic            Yes           No              Yes         Yes
#
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train=pd.get_dummies(x_train)
x_test=pd.get_dummies(x_test)

# %%
y_train.shape
# Out:
# (5634,)

# %%
y_train
# Out:
# 2142    0
# 1623    0
# 6074    1
# 1362    1
# 6754    0
#        ..
# 3772    1
# 5191    0
# 5226    0
# 5390    1
# 860     0
# Name: Churn, Length: 5634, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
accuracy_score(y_test,y_pred)
# Out:
# 0.7991483321504613

# %%
from sklearn.model_selection import cross_val_score
cv_scores=cross_val_score(model,x_train,y_train,cv=5)

# %%
cv_scores
# Out:
# array([0.77728483, 0.78438332, 0.7905945 , 0.76220053, 0.77619893])

# %% [markdown]
# # we use dumb classifier to certian that the model provide better because the value of the model accuracy >75% and the dumb classifier accuracy<75% that certian the model is suitable

# %%
from sklearn.base import BaseEstimator

class Never5Classifier(BaseEstimator):
 def fit(self, x, y):
  pass
 def predict(self, X):
  return np.zeros((len(X), 1), dtype=bool)

# %%
never_5_clf = Never5Classifier()
cross_val_score(never_5_clf, x_train, y_train, cv=3, scoring="accuracy")
# Out:
# array([0.73109691, 0.72790202, 0.74440895])

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[922, 114],
#        [169, 204]])

# %%
from sklearn.metrics import precision_score,recall_score,f1_score
precision_score(y_test,y_pred)
# Out:
# 0.6415094339622641

# %%
recall_score(y_test,y_pred)
# Out:
# 0.546916890080429

# %%
f1_score(y_test,y_pred)
# Out:
# 0.5904486251808972
